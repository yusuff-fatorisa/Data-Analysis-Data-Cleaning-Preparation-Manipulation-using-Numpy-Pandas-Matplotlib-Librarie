# %% [markdown]
# ### Hello, welcome to another lesson. This lesson is in continuation of the series on using Python and its vast Libraries [ Numpy, Pandas, Matplotlib etc ] for Data Analysis Tasks.

# %% [markdown]
# ### Most importantly, it's about sharing my growth process on this career path, and also to encourage you on what you're doing. Be encouraged and keep doing it, even if it means doing it poorly till you gain mastery of it

# %% [markdown]
# ### First, you need to import the necessary Libraries required for task execution, then remember to add "%matplotlib inline" for display of plots.
#
# ### This dataset is another excel file downloaded from the website of "WHO". It's readily available for the public access
#
# ### Import the file and read the first 5 lines of the DataFrame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_excel("TB Outcomes Completed.xlsx", sheet_name = 0, index_col = 0)
dataset.head()
# Out:
#             iso2 iso3  iso_numeric g_whoregion  year  rep_meth   new_sp_coh  \
# country
# Afghanistan   AF  AFG            4         EMR  1994       100  10863.51162
# Afghanistan   AF  AFG            4         EMR  1995       100  10863.51162
# Afghanistan   AF  AFG            4         EMR  1996       100  10863.51162
# Afghanistan   AF  AFG            4         EMR  1997       100   2001.00000
# Afghanistan   AF  AFG            4         EMR  1998       100   2913.00000
#
#               new_sp_cur  new_sp_cmplt  new_sp_died  ...     mdr_coh  \
# country                                              ...
# Afghanistan  7887.186906    964.721656   430.904174  ...  334.331807
# Afghanistan  7887.186906    964.721656   430.904174  ...  334.331807
# Afghanistan  7887.186906    964.721656   430.904174  ...  334.331807
# Afghanistan   786.000000    108.000000    33.000000  ...  334.331807
# Afghanistan   772.000000    199.000000    48.000000  ...  334.331807
#
#                mdr_succ   mdr_fail   mdr_died   mdr_lost   xdr_coh  xdr_succ  \
# country
# Afghanistan  182.062827  30.547632  55.285032  52.715739  25.20448  8.472963
# Afghanistan  182.062827  30.547632  55.285032  52.715739  25.20448  8.472963
# Afghanistan  182.062827  30.547632  55.285032  52.715739  25.20448  8.472963
# Afghanistan  182.062827  30.547632  55.285032  52.715739  25.20448  8.472963
# Afghanistan  182.062827  30.547632  55.285032  52.715739  25.20448  8.472963
#
#              xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan  4.977812  7.383028  2.884202
# Afghanistan  4.977812  7.383028  2.884202
# Afghanistan  4.977812  7.383028  2.884202
# Afghanistan  4.977812  7.383028  2.884202
# Afghanistan  4.977812  7.383028  2.884202
#
# [5 rows x 71 columns]

# %% [markdown]
# ### Next, you should familiarize yourself with the nature of the Dataset. This would give you an idea of what the dataset looks like

# %%
dataset.shape
# Out:
# (5118, 71)

# %%
dataset.dtypes
# Out:
# iso2            object
# iso3            object
# iso_numeric      int64
# g_whoregion     object
# year             int64
#                 ...
# xdr_coh        float64
# xdr_succ       float64
# xdr_fail       float64
# xdr_died       float64
# xdr_lost       float64
# Length: 71, dtype: object

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (5118, 71)

# %%
dataset.size
# Out:
# 363378

# %%
dataset.index
# Out:
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='country', length=5118)

# %%
dataset.columns
# Out:
# Index(['iso2', 'iso3', 'iso_numeric', 'g_whoregion', 'year', 'rep_meth',
#        'new_sp_coh', 'new_sp_cur', 'new_sp_cmplt', 'new_sp_died',
#        'new_sp_fail', 'new_sp_def', 'c_new_sp_tsr', 'new_snep_coh',
#        'new_snep_cmplt', 'new_snep_died', 'new_snep_fail', 'new_snep_def',
#        'c_new_snep_tsr', 'ret_coh', 'ret_cur', 'ret_cmplt', 'ret_died',
#        'ret_fail', 'ret_def', 'hiv_new_sp_coh', 'hiv_new_sp_cur',
#        'hiv_new_sp_cmplt', 'hiv_new_sp_died', 'hiv_new_sp_fail',
#        'hiv_new_sp_def', 'hiv_new_snep_coh', 'hiv_new_snep_cmplt',
#        'hiv_new_snep_died', 'hiv_new_snep_fail', 'hiv_new_snep_def',
#        'hiv_ret_coh', 'hiv_ret_cur', 'hiv_ret_cmplt', 'hiv_ret_died',
#        'hiv_ret_fail', 'hiv_ret_def', 'rel_with_new_flg', 'newrel_coh',
#        'newrel_succ', 'newrel_fail', 'newrel_died', 'newrel_lost', 'c_new_tsr',
#        'ret_nrel_coh', 'ret_nrel_succ', 'ret_nrel_fail', 'ret_nrel_died',
#        'ret_nrel_lost', 'c_ret_tsr', 'tbhiv_coh', 'tbhiv_succ', 'tbhiv_fail',
#        'tbhiv_died', 'tbhiv_lost', 'c_tbhiv_tsr', 'mdr_coh', 'mdr_succ',
#        'mdr_fail', 'mdr_died', 'mdr_lost', 'xdr_coh', 'xdr_succ', 'xdr_fail',
#        'xdr_died', 'xdr_lost'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#        iso_numeric         year     rep_meth    new_sp_coh     new_sp_cur  \
# count  5118.000000  5118.000000  5118.000000    5118.00000    5118.000000
# mean    432.063111  2005.565651   100.528136   10863.51162    7887.186906
# std     253.529561     6.926333     0.825792   35233.88547   28455.963769
# min       4.000000  1994.000000   100.000000       0.00000       0.000000
# 25%     212.000000  2000.000000   100.000000     689.00000     395.500000
# 50%     430.000000  2006.000000   100.000000   10751.50000    7887.186906
# 75%     643.000000  2012.000000   101.000000   10863.51162    7887.186906
# max     894.000000  2017.000000   102.000000  642321.00000  544731.000000
#
#        new_sp_cmplt   new_sp_died   new_sp_fail    new_sp_def  c_new_sp_tsr  \
# count   5118.000000   5118.000000   5118.000000   5118.000000   5118.000000
# mean     964.721656    430.904174    183.931226    612.922218     75.762475
# std     2521.550115   1235.695062    609.162128   1813.530176     12.486306
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       81.000000     38.000000      9.000000     49.000000     75.762475
# 50%      964.721656    430.904174    183.931226    612.922218     75.762475
# 75%      964.721656    430.904174    183.931226    612.922218     81.000000
# max    64938.000000  27005.000000  12505.000000  35469.000000    100.000000
#
#        ...       mdr_coh      mdr_succ     mdr_fail     mdr_died     mdr_lost  \
# count  ...   5118.000000   5118.000000  5118.000000  5118.000000  5118.000000
# mean   ...    334.331807    182.062827    30.547632    55.285032    52.715739
# std    ...   1137.915599    566.443670   120.105034   208.986493   187.011733
# min    ...      0.000000      0.000000     0.000000     0.000000     0.000000
# 25%    ...     34.000000     24.000000     1.000000     6.000000     4.000000
# 50%    ...    334.331807    182.062827    30.547632    55.285032    52.715739
# 75%    ...    334.331807    182.062827    30.547632    55.285032    52.715739
# max    ...  33197.000000  15872.000000  2916.000000  6144.000000  6324.000000
#
#            xdr_coh     xdr_succ     xdr_fail     xdr_died     xdr_lost
# count  5118.000000  5118.000000  5118.000000  5118.000000  5118.000000
# mean     25.204480     8.472963     4.977812     7.383028     2.884202
# std      96.571655    31.292655    20.156968    28.527600    10.331911
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      19.250000     8.472963     4.977812     7.383028     2.884202
# 50%      25.204480     8.472963     4.977812     7.383028     2.884202
# 75%      25.204480     8.472963     4.977812     7.383028     2.884202
# max    2909.000000  1094.000000   633.000000  1016.000000   348.000000
#
# [8 rows x 68 columns]

# %% [markdown]
# ### Next, check the dataset for duplicated values and treat them accordingly if any

# %%
dataset[dataset.duplicated()].sum()
# Out:
# iso2           0.0
# iso3           0.0
# iso_numeric    0.0
# g_whoregion    0.0
# year           0.0
#               ...
# xdr_coh        0.0
# xdr_succ       0.0
# xdr_fail       0.0
# xdr_died       0.0
# xdr_lost       0.0
# Length: 71, dtype: float64

# %% [markdown]
# ### The Dataset contains no duplicate values as it's indicated  in the results above. That's a plus, so proceed to othet data Preparation steps

# %% [markdown]
# ### The Dataset contains no null values because I'm working with the version of the file which ive cleaned and manipulate beforehand. When you get your file, it will require some data cleaning and formatting before it'll be ready for analysis and exploration

# %%
dataset.isna().sum()
# Out:
# iso2           0
# iso3           0
# iso_numeric    0
# g_whoregion    0
# year           0
#               ..
# xdr_coh        0
# xdr_succ       0
# xdr_fail       0
# xdr_died       0
# xdr_lost       0
# Length: 71, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5118 entries, Afghanistan to Zimbabwe
# Data columns (total 71 columns):
# iso2                  5118 non-null object
# iso3                  5118 non-null object
# iso_numeric           5118 non-null int64
# g_whoregion           5118 non-null object
# year                  5118 non-null int64
# rep_meth              5118 non-null int64
# new_sp_coh            5118 non-null float64
# new_sp_cur            5118 non-null float64
# new_sp_cmplt          5118 non-null float64
# new_sp_died           5118 non-null float64
# new_sp_fail           5118 non-null float64
# new_sp_def            5118 non-null float64
# c_new_sp_tsr          5118 non-null float64
# new_snep_coh          5118 non-null float64
# new_snep_cmplt        5118 non-null float64
# new_snep_died         5118 non-null float64
# new_snep_fail         5118 non-null float64
# new_snep_def          5118 non-null float64
# c_new_snep_tsr        5118 non-null float64
# ret_coh               5118 non-null float64
# ret_cur               5118 non-null float64
# ret_cmplt             5118 non-null float64
# ret_died              5118 non-null float64
# ret_fail              5118 non-null float64
# ret_def               5118 non-null float64
# hiv_new_sp_coh        5118 non-null float64
# hiv_new_sp_cur        5118 non-null float64
# hiv_new_sp_cmplt      5118 non-null float64
# hiv_new_sp_died       5118 non-null float64
# hiv_new_sp_fail       5118 non-null float64
# hiv_new_sp_def        5118 non-null float64
# hiv_new_snep_coh      5118 non-null float64
# hiv_new_snep_cmplt    5118 non-null float64
# hiv_new_snep_died     5118 non-null float64
# hiv_new_snep_fail     5118 non-null float64
# hiv_new_snep_def      5118 non-null float64
# hiv_ret_coh           5118 non-null float64
# hiv_ret_cur           5118 non-null float64
# hiv_ret_cmplt         5118 non-null float64
# hiv_ret_died          5118 non-null float64
# hiv_ret_fail          5118 non-null float64
# hiv_ret_def           5118 non-null float64
# rel_with_new_flg      5118 non-null float64
# newrel_coh            5118 non-null float64
# newrel_succ           5118 non-null float64
# newrel_fail           5118 non-null float64
# newrel_died           5118 non-null float64
# newrel_lost           5118 non-null float64
# c_new_tsr             5118 non-null float64
# ret_nrel_coh          5118 non-null float64
# ret_nrel_succ         5118 non-null float64
# ret_nrel_fail         5118 non-null float64
# ret_nrel_died         5118 non-null float64
# ret_nrel_lost         5118 non-null float64
# c_ret_tsr             5118 non-null float64
# tbhiv_coh             5118 non-null float64
# tbhiv_succ            5118 non-null float64
# tbhiv_fail            5118 non-null float64
# tbhiv_died            5118 non-null float64
# tbhiv_lost            5118 non-null float64
# c_tbhiv_tsr           5118 non-null float64
# mdr_coh               5118 non-null float64
# mdr_succ              5118 non-null float64
# mdr_fail              5118 non-null float64
# mdr_died              5118 non-null float64
# mdr_lost              5118 non-null float64
# xdr_coh               5118 non-null float64
# xdr_succ              5118 non-null float64
# xdr_fail              5118 non-null float64
# xdr_died              5118 non-null float64
# xdr_lost              5118 non-null float64
# dtypes: float64(65), int64(3), object(3)
# memory usage: 2.7+ MB

# %% [markdown]
# ### Checking the various types of data types contained in the datset and summing it together. It's just part of understanding the data in question

# %%
dataset.dtypes.value_counts()
# Out:
# float64    65
# int64       3
# object      3
# dtype: int64

# %% [markdown]
# ### The dataset is now ready for analysis and exploration to derive insights.
#
# ### The insights and visualization you derive from any Dataset depends on your goal. For the sake of practice and learning, most of what will be done here will be on random basis just to help you build your skills

# %% [markdown]
# ### First,  you'll determine how many countries are represented in the dataset

# %%
countries_present = dataset.index.unique()
countries_present1 = len(countries_present)
countries_present1
# Out:
# 218

# %%
print("There are",countries_present1,"countries represented on this dataset")
# Out:
# There are 218 countries represented on this dataset

# %% [markdown]
# ### Next,  let's determine the number of regions represented in this dataset

# %%
regions_present = dataset["g_whoregion"].unique()
regions_present1 = len(regions_present)
regions_present1
# Out:
# 6

# %%
print("There are", regions_present1,"regions represented on this dataset")
# Out:
# There are 6 regions represented on this dataset

# %% [markdown]
# ### A visual plot of the regions in the dataset is good to plot at this stage. It's represented by a horizontal bar chart . Even if a pie chart is utilized, it'll still work perfectly.

# %%
regs = dataset["g_whoregion"].groupby(dataset['g_whoregion'])
regs1 = regs.size()
regs11 = regs1.sort_values()
regs11.plot.barh()
plt.title("Regions Present", alpha = 0.85)
plt.ylabel("Regions", alpha = 0.7, fontstyle = 'italic')
# Out:
# Text(0, 0.5, 'Regions')

# %% [markdown]
# ### Next is to determine the unique number of years that was covered in the dataset

# %%
years_covered = dataset.year.unique()
years_covered1 = len(years_covered)
years_covered1
# Out:
# 24

# %%
print('The number of years covered in this dataset is',years_covered1,"years. It spans between", years_covered.min(),"to",years_covered.max())
# Out:
# The number of years covered in this dataset is 24 years. It spans between 1994 to 2017

# %% [markdown]
# ### Next, Let's extract the number of countries that's present in each region

# %%
curled = dataset["rep_meth"].groupby([dataset["g_whoregion"],dataset.index])
curled1 = curled.size()
curled1
# Out:
# g_whoregion  country
# AFR          Algeria                      24
#              Angola                       24
#              Benin                        24
#              Botswana                     24
#              Burkina Faso                 24
#                                           ..
# WPR          Tonga                        24
#              Tuvalu                       24
#              Vanuatu                      24
#              Viet Nam                     24
#              Wallis and Futuna Islands    24
# Name: rep_meth, Length: 218, dtype: int64

# %%
curled11 = curled1.unstack(0)
curled11
# Out:
# g_whoregion                 AFR  AMR   EMR   EUR  SEA   WPR
# country
# Afghanistan                 NaN  NaN  24.0   NaN  NaN   NaN
# Albania                     NaN  NaN   NaN  24.0  NaN   NaN
# Algeria                    24.0  NaN   NaN   NaN  NaN   NaN
# American Samoa              NaN  NaN   NaN   NaN  NaN  24.0
# Andorra                     NaN  NaN   NaN  24.0  NaN   NaN
# ...                         ...  ...   ...   ...  ...   ...
# Wallis and Futuna Islands   NaN  NaN   NaN   NaN  NaN  24.0
# West Bank and Gaza Strip    NaN  NaN  24.0   NaN  NaN   NaN
# Yemen                       NaN  NaN  24.0   NaN  NaN   NaN
# Zambia                     24.0  NaN   NaN   NaN  NaN   NaN
# Zimbabwe                   24.0  NaN   NaN   NaN  NaN   NaN
#
# [218 rows x 6 columns]

# %% [markdown]
# ### A dataframe containing the regions and the countries has been extracted. The next few steps will be to extract each region and its corresponding countries.

# %% [markdown]
# ### Now let's extract the information which reveals the  number of countries in the AFR Region

# %%
AFR_countries = curled11.AFR[curled11.AFR > 0]
AFR_countries1 = AFR_countries.count()
AFR_countries1
# Out:
# 47

# %%
print("There are", AFR_countries1,"countries in \"AFR\" region")
# Out:
# There are 47 countries in "AFR" region

# %% [markdown]
# ### Next, Let's extract the information which reveals the number of countries in the AMR region

# %%
AMR_countries = curled11.AMR[curled11.AMR > 0]
AMR_countries1 = AMR_countries.count()
AMR_countries1
# Out:
# 47

# %%
print("There are",AMR_countries1,"countries in the \"AMR\" region")
# Out:
# There are 47 countries in the "AMR" region

# %% [markdown]
# ### Next, I'm going to extract the information that reveals the countries in the EMR Region

# %%
EMR_countries = curled11.EMR[curled11.EMR > 0]
EMR_countries1 = EMR_countries.count()
EMR_countries1
# Out:
# 22

# %%
print("There are",EMR_countries1,"countries in the \"EMR\" Region")
# Out:
# There are 22 countries in the "EMR" Region

# %% [markdown]
# ### Next, Let's extract the information which reveals the countries in the EUR Region

# %%
EUR_countries = curled11.EUR[curled11.EUR > 0]
EUR_countries1 = EUR_countries.count()
EUR_countries1
# Out:
# 55

# %%
print("There are",EUR_countries1,"countries in the \"EUR\" Region")
# Out:
# There are 55 countries in the "EUR" Region

# %% [markdown]
# ### Next, Let's extract the information that reveals the number of countries in the SEA Region

# %%
SEA_countries = curled11.SEA[curled11.SEA > 0]
SEA_countries1 = SEA_countries.count()
SEA_countries1
# Out:
# 11

# %%
print("There are",SEA_countries1,"countries in the \"SEA\" Region")
# Out:
# There are 11 countries in the "SEA" Region

# %% [markdown]
# ### Next, Let's extract the information that reveals the countries in the WPR Region

# %%
WPR_countries = curled11.WPR[curled11.WPR > 0]
WPR_countries1 = WPR_countries.count()
WPR_countries1
# Out:
# 36

# %%
print("There are",WPR_countries1,"countries in the \"WPR\" Region")
# Out:
# There are 36 countries in the "WPR" Region

# %%
dataset.tail()
# Out:
#          iso2 iso3  iso_numeric g_whoregion  year  rep_meth   new_sp_coh  \
# country
# Zimbabwe   ZW  ZWE          716         AFR  2013       100  10863.51162
# Zimbabwe   ZW  ZWE          716         AFR  2014       100  10863.51162
# Zimbabwe   ZW  ZWE          716         AFR  2015       100  10863.51162
# Zimbabwe   ZW  ZWE          716         AFR  2016       100  10863.51162
# Zimbabwe   ZW  ZWE          716         AFR  2017       100  10863.51162
#
#            new_sp_cur  new_sp_cmplt  new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                           ...
# Zimbabwe  7887.186906    964.721656   430.904174  ...  351.000000  207.000000
# Zimbabwe  7887.186906    964.721656   430.904174  ...  381.000000  193.000000
# Zimbabwe  7887.186906    964.721656   430.904174  ...  433.000000  189.000000
# Zimbabwe  7887.186906    964.721656   430.904174  ...  488.000000  276.000000
# Zimbabwe  7887.186906    964.721656   430.904174  ...  334.331807  182.062827
#
#            mdr_fail    mdr_died   mdr_lost   xdr_coh  xdr_succ  xdr_fail  \
# country
# Zimbabwe   1.000000   43.000000  14.000000  25.20448  8.472963  4.977812
# Zimbabwe   6.000000   66.000000  21.000000   0.00000  0.000000  0.000000
# Zimbabwe   8.000000   75.000000  22.000000   5.00000  4.000000  0.000000
# Zimbabwe   0.000000  149.000000  44.000000   5.00000  0.000000  1.000000
# Zimbabwe  30.547632   55.285032  52.715739  25.20448  8.472963  4.977812
#
#           xdr_died  xdr_lost
# country
# Zimbabwe  7.383028  2.884202
# Zimbabwe  0.000000  0.000000
# Zimbabwe  1.000000  0.000000
# Zimbabwe  2.000000  1.000000
# Zimbabwe  7.383028  2.884202
#
# [5 rows x 71 columns]

# %% [markdown]
# ## Next, I'm going to determine the specific regions and the number of countries in that region that were attended to in each of the years contained in the dataset.
#
# ### I strongly feel plotting visualization for this part of the analysis is not so much appropriate. If you decide that doing so will make more meaning, feel free to unleash your imagination

# %%
print('The number of years covered in this dataset is',years_covered1,"years. It spans between", years_covered.min(),"to",years_covered.max())
# Out:
# The number of years covered in this dataset is 24 years. It spans between 1994 to 2017

# %%
extract094 = dataset[dataset.year == 1994]
extract094
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  1994       100
# Albania                     AL  ALB            8         EUR  1994       100
# Algeria                     DZ  DZA           12         AFR  1994       100
# American Samoa              AS  ASM           16         WPR  1994       102
# Andorra                     AD  AND           20         EUR  1994       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  1994       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  1994       102
# Yemen                       YE  YEM          887         EMR  1994       100
# Zambia                      ZM  ZMB          894         AFR  1994       100
# Zimbabwe                    ZW  ZWE          716         AFR  1994       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                     7253.00000  7887.186906   5655.000000
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands      5.00000     0.000000      4.000000
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                       3351.00000  1035.000000    291.000000
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                    6724.00000  1701.000000   1772.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...  334.331807  182.062827
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     199.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                     430.904174  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands     1.000000  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                        21.000000  ...  334.331807  182.062827
# Zambia                      430.904174  ...  334.331807  182.062827
# Zimbabwe                    645.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract094.year.unique()
# Out:
# array([1994], dtype=int64)

# %%
count094 = extract094.rep_meth.groupby(extract094.index)
count94 = count094.count()
count94.head(20)
# Out:
# country
# Afghanistan            1
# Albania                1
# Algeria                1
# American Samoa         1
# Andorra                1
# Angola                 1
# Anguilla               1
# Antigua and Barbuda    1
# Argentina              1
# Armenia                1
# Aruba                  1
# Australia              1
# Austria                1
# Azerbaijan             1
# Bahamas                1
# Bahrain                1
# Bangladesh             1
# Barbados               1
# Belarus                1
# Belgium                1
# Name: rep_meth, dtype: int64

# %%
regions094 = extract094.rep_meth.groupby(extract094["g_whoregion"])
regions94 = regions094.size()
regions94
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    10
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract094.year.unique(),",",len(count94.index),"Countries were attended to and",len(regions94.index),"Regions were attended to respectively")
# Out:
# In the year [1994] , 211 Countries were attended to and 6 Regions were attended to respectively

# %%
extract095 = dataset[dataset.year == 1995]
extract095
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  1995       100
# Albania                     AL  ALB            8         EUR  1995       100
# Algeria                     DZ  DZA           12         AFR  1995       100
# American Samoa              AS  ASM           16         WPR  1995       100
# Andorra                     AD  AND           20         EUR  1995       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  1995       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  1995       100
# Yemen                       YE  YEM          887         EMR  1995       100
# Zambia                      ZM  ZMB          894         AFR  1995       100
# Zimbabwe                    ZW  ZWE          716         AFR  1995       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                    10863.51162  7887.186906    964.721656
# American Samoa                 4.00000     4.000000      0.000000
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip      13.00000    13.000000    964.721656
# Yemen                       3681.00000  1598.000000    333.000000
# Zambia                      5957.00000  2815.000000   1351.000000
# Zimbabwe                    9702.00000  3137.000000   2032.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...  334.331807  182.062827
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     430.904174  ...  334.331807  182.062827
# American Samoa                0.000000  ...  334.331807  182.062827
# Andorra                     430.904174  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                        40.000000  ...  334.331807  182.062827
# Zambia                      391.000000  ...  334.331807  182.062827
# Zimbabwe                    983.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract095.year.unique()
# Out:
# array([1995], dtype=int64)

# %%
count095 = extract095.rep_meth.groupby(extract095.index)
count95 = count095.count()
count95
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 211, dtype: int64

# %%
regions095 = extract095.rep_meth.groupby(extract095["g_whoregion"])
regions95 = regions095.size()
regions95
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    10
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract095.year.unique(),",",len(count95.index),"countries were attended to and",len(regions95.index),"Regions were attended to respectively")
# Out:
# In the year [1995] , 211 countries were attended to and 6 Regions were attended to respectively

# %%
extract096 = dataset[dataset.year == 1996]
extract096
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  1996       100
# Albania                     AL  ALB            8         EUR  1996       100
# Algeria                     DZ  DZA           12         AFR  1996       100
# American Samoa              AS  ASM           16         WPR  1996       100
# Andorra                     AD  AND           20         EUR  1996       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  1996       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  1996       100
# Yemen                       YE  YEM          887         EMR  1996       100
# Zambia                      ZM  ZMB          894         AFR  1996       100
# Zimbabwe                    ZW  ZWE          716         AFR  1996       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                     6860.00000  5630.000000    241.000000
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                       4221.00000  1936.000000    253.000000
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   11965.00000  3836.000000      0.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...  334.331807  182.062827
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     191.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                     430.904174  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                        54.000000  ...  334.331807  182.062827
# Zambia                      430.904174  ...  334.331807  182.062827
# Zimbabwe                    947.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract096.year.unique()
# Out:
# array([1996], dtype=int64)

# %%
count096 = extract096.rep_meth.groupby(extract096.index)
count96 = count096.size()
count96
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 211, dtype: int64

# %%
regions096 = extract096.rep_meth.groupby(extract096["g_whoregion"])
regions96 = regions096.size()
regions96
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    10
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract096.year.unique(),",",len(count96.index),"Countries were attended to and",len(regions96.index),"were attended to respectively")
# Out:
# In the year [1996] , 211 Countries were attended to and 6 were attended to respectively

# %%
extract097 = dataset[dataset.year == 1997]
extract097
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  1997       100
# Albania                     AL  ALB            8         EUR  1997       100
# Algeria                     DZ  DZA           12         AFR  1997       100
# American Samoa              AS  ASM           16         WPR  1997       100
# Andorra                     AD  AND           20         EUR  1997       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  1997       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  1997       100
# Yemen                       YE  YEM          887         EMR  1997       100
# Zambia                      ZM  ZMB          894         AFR  1997       100
# Zimbabwe                    ZW  ZWE          716         AFR  1997       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                 2001.00000   786.000000    108.000000
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                     6860.00000  5630.000000    241.000000
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                       4365.00000  2608.000000    439.000000
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   12410.00000  6361.000000   2175.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                  33.000000  ...  334.331807  182.062827
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     191.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                     430.904174  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       103.000000  ...  334.331807  182.062827
# Zambia                      430.904174  ...  334.331807  182.062827
# Zimbabwe                   1260.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract097.year.unique()
# Out:
# array([1997], dtype=int64)

# %%
count097 = extract097.rep_meth.groupby(extract097.index)
count97 = count097.size()
count97
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 211, dtype: int64

# %%
regions097 = extract097.rep_meth.groupby(extract097["g_whoregion"])
regions97 = regions097.size()
regions97
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    10
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract097.year.unique(),",",len(count97.index),"Countries were attended to and",len(regions97.index),"Regions were attended to respectively")
# Out:
# In the year [1997] , 211 Countries were attended to and 6 Regions were attended to respectively

# %%
extract098 = dataset[dataset.year == 1998]
extract098
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  1998       100
# Albania                     AL  ALB            8         EUR  1998       100
# Algeria                     DZ  DZA           12         AFR  1998       100
# American Samoa              AS  ASM           16         WPR  1998       100
# Andorra                     AD  AND           20         EUR  1998       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  1998       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  1998       100
# Yemen                       YE  YEM          887         EMR  1998       100
# Zambia                      ZM  ZMB          894         AFR  1998       100
# Zimbabwe                    ZW  ZWE          716         AFR  1998       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                 2913.00000   772.000000    199.000000
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                     2490.00000  1741.000000    964.721656
# American Samoa                 4.00000     2.000000    964.721656
# Andorra                        2.00000     0.000000      2.000000
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                       4983.00000  2889.000000    465.000000
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   12748.00000  6420.000000   2445.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                  48.000000  ...  334.331807  182.062827
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                      80.000000  ...  334.331807  182.062827
# American Samoa                0.000000  ...  334.331807  182.062827
# Andorra                       0.000000  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       127.000000  ...  334.331807  182.062827
# Zambia                      430.904174  ...  334.331807  182.062827
# Zimbabwe                   1272.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract098.year.unique()
# Out:
# array([1998], dtype=int64)

# %%
count098 = extract098.rep_meth.groupby(extract098.index)
count98 = count098.size()
count98
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 211, dtype: int64

# %%
regions098 = extract098.rep_meth.groupby(extract098["g_whoregion"])
regions98 = regions098.size()
regions98
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    10
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract098.year.unique(),",",len(count98.index),"Countries were attended to and",len(regions98.index),"were attended to respectively")
# Out:
# In the year [1998] , 211 Countries were attended to and 6 were attended to respectively

# %%
extract099 = dataset[dataset.year == 1999]
extract099
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  1999       100
# Albania                     AL  ALB            8         EUR  1999       100
# Algeria                     DZ  DZA           12         AFR  1999       100
# American Samoa              AS  ASM           16         WPR  1999       100
# Andorra                     AD  AND           20         EUR  1999       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  1999       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  1999       100
# Yemen                       YE  YEM          887         EMR  1999       100
# Zambia                      ZM  ZMB          894         AFR  1999       100
# Zimbabwe                    ZW  ZWE          716         AFR  1999       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                 2039.00000  1571.000000    189.000000
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                     7622.00000  6621.000000    964.721656
# American Samoa                 3.00000     3.000000      0.000000
# Andorra                        3.00000  7887.186906      2.000000
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                       5463.00000  3482.000000    561.000000
# Zambia                     11645.00000  5808.000000   2238.000000
# Zimbabwe                   12791.00000  7535.000000   1749.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                  83.000000  ...  334.331807  182.062827
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     191.000000  ...  334.331807  182.062827
# American Samoa                0.000000  ...  334.331807  182.062827
# Andorra                     430.904174  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       154.000000  ...  334.331807  182.062827
# Zambia                      850.000000  ...  334.331807  182.062827
# Zimbabwe                   1281.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract099.year.unique()
# Out:
# array([1999], dtype=int64)

# %%
count099 = extract099.rep_meth.groupby(extract099.index)
count99 = count099.size()
count99
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 211, dtype: int64

# %%
regions099 = extract099.rep_meth.groupby(extract099["g_whoregion"])
regions99 = regions099.size()
regions99
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    10
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract099.year.unique(),",",len(count99.index),"Countries were attended to and",len(regions99.index),"Regions were attended to respectively")
# Out:
# In the year [1999] , 211 Countries were attended to and 6 Regions were attended to respectively

# %%
extract000 = dataset[dataset.year == 2000]
extract000
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2000       100
# Albania                     AL  ALB            8         EUR  2000       100
# Algeria                     DZ  DZA           12         AFR  2000       100
# American Samoa              AS  ASM           16         WPR  2000       100
# Andorra                     AD  AND           20         EUR  2000       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2000       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  2000       100
# Yemen                       YE  YEM          887         EMR  2000       100
# Zambia                      ZM  ZMB          894         AFR  2000       100
# Zimbabwe                    ZW  ZWE          716         AFR  2000       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                 3136.00000  2396.000000    283.000000
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                     8328.00000  6690.000000    583.000000
# American Samoa                 2.00000     0.000000      2.000000
# Andorra                        2.00000  7887.186906      1.000000
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                       5565.00000  3273.000000    707.000000
# Zambia                      7014.00000  3348.000000   1358.000000
# Zimbabwe                   14392.00000  8820.000000   1092.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 107.000000  ...  334.331807  182.062827
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                      56.000000  ...  334.331807  182.062827
# American Samoa                0.000000  ...  334.331807  182.062827
# Andorra                     430.904174  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       191.000000  ...  334.331807  182.062827
# Zambia                      478.000000  ...  334.331807  182.062827
# Zimbabwe                   1656.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract000.year.unique()
# Out:
# array([2000], dtype=int64)

# %%
count000 = extract000.rep_meth.groupby(extract000.index)
count00 = count000.size()
count00
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 211, dtype: int64

# %%
regions000 = extract000.rep_meth.groupby(extract000["g_whoregion"])
regions00 = regions000.size()
regions00
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    10
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract000.year.unique(),",",len(count00.index),"Countries were attended to and",len(regions00.index),"Regions were attended to respectively")
# Out:
# In the year [2000] , 211 Countries were attended to and 6 Regions were attended to respectively

# %%
extract001 = dataset[dataset["year"] == 2001]
extract001
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2001       100
# Albania                     AL  ALB            8         EUR  2001       100
# Algeria                     DZ  DZA           12         AFR  2001       100
# American Samoa              AS  ASM           16         WPR  2001       100
# Andorra                     AD  AND           20         EUR  2001       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2001       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  2001       100
# Yemen                       YE  YEM          887         EMR  2001       100
# Zambia                      ZM  ZMB          894         AFR  2001       100
# Zimbabwe                    ZW  ZWE          716         AFR  2001       100
#
#                             new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                 6292.00000   3305.000000   2004.000000
# Albania                      171.00000     76.000000     80.000000
# Algeria                     8361.00000   4561.000000   2462.000000
# American Samoa                 2.00000   7887.186906      2.000000
# Andorra                        1.00000      1.000000      0.000000
# ...                                ...           ...           ...
# Wallis and Futuna Islands      1.00000      1.000000    964.721656
# West Bank and Gaza Strip   10863.51162   7887.186906    964.721656
# Yemen                       4968.00000   3206.000000    594.000000
# Zambia                     13024.00000   7246.000000   2429.000000
# Zimbabwe                   16569.00000  10521.000000   1176.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 238.000000  ...  334.331807  182.062827
# Albania                       2.000000  ...  334.331807  182.062827
# Algeria                     195.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                       0.000000  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       157.000000  ...  334.331807  182.062827
# Zambia                     1450.000000  ...  334.331807  182.062827
# Zimbabwe                   1972.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract001.year.unique()
# Out:
# array([2001], dtype=int64)

# %%
count001 = extract001.rep_meth.groupby(extract001.index)
count01 = count001.size()
count01
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 211, dtype: int64

# %%
regions001 = extract001.rep_meth.groupby(extract001["g_whoregion"])
regions01 = regions001.size()
regions01
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    10
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract001.year.unique(),",",len(count01.index),"Countries were attended to and",len(regions01.index),"were attended to respectively")
# Out:
# In the year [2001] , 211 Countries were attended to and 6 were attended to respectively

# %%
extract002 = dataset[dataset.year == 2002]
extract002
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2002       100
# Albania                     AL  ALB            8         EUR  2002       100
# Algeria                     DZ  DZA           12         AFR  2002       100
# American Samoa              AS  ASM           16         WPR  2002       100
# Andorra                     AD  AND           20         EUR  2002       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2002       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  2002       100
# Yemen                       YE  YEM          887         EMR  2002       100
# Zambia                      ZM  ZMB          894         AFR  2002       100
# Zimbabwe                    ZW  ZWE          716         AFR  2002       100
#
#                            new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                    7780.0   4668.000000   2090.000000
# Albania                         225.0     98.000000     91.000000
# Algeria                        9200.0   6631.000000   1560.000000
# American Samoa                    1.0   7887.186906      1.000000
# Andorra                           3.0      3.000000      0.000000
# ...                               ...           ...           ...
# Wallis and Futuna Islands         5.0      5.000000      0.000000
# West Bank and Gaza Strip         10.0     10.000000    964.721656
# Yemen                          4204.0   2864.000000    508.000000
# Zambia                        16351.0  10410.000000   2658.000000
# Zimbabwe                      15941.0   9833.000000    898.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 308.000000  ...  334.331807  182.062827
# Albania                       3.000000  ...  334.331807  182.062827
# Algeria                     177.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                       0.000000  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands     0.000000  ...    0.000000    0.000000
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       144.000000  ...  334.331807  182.062827
# Zambia                     1811.000000  ...  334.331807  182.062827
# Zimbabwe                   1801.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands   0.000000   0.000000   0.000000  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [212 rows x 71 columns]

# %%
extract002.year.unique()
# Out:
# array([2002], dtype=int64)

# %%
count002 = extract002.rep_meth.groupby(extract002.index)
count02 = count002.size()
count02
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 212, dtype: int64

# %%
regions002 = extract002.rep_meth.groupby(extract002["g_whoregion"])
regions02 = regions002.size()
regions02
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract002.year.unique(),",",len(count02.index),"Countries were attended to and",len(regions02.index),"were attended to respectively")
# Out:
# In the year [2002] , 212 Countries were attended to and 6 were attended to respectively

# %%
extract003 = dataset[dataset.year == 2003]
extract003
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2003       100
# Albania                     AL  ALB            8         EUR  2003       100
# Algeria                     DZ  DZA           12         AFR  2003       100
# American Samoa              AS  ASM           16         WPR  2003       100
# Andorra                     AD  AND           20         EUR  2003       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2003       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  2003       100
# Yemen                       YE  YEM          887         EMR  2003       100
# Zambia                      ZM  ZMB          894         AFR  2003       100
# Zimbabwe                    ZW  ZWE          716         AFR  2003       100
#
#                             new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                 6793.00000   5505.000000    340.000000
# Albania                      212.00000    104.000000     82.000000
# Algeria                     8521.00000   6548.000000   1079.000000
# American Samoa                 2.00000      2.000000    964.721656
# Andorra                        6.00000      6.000000      0.000000
# ...                                ...           ...           ...
# Wallis and Futuna Islands  10863.51162   7887.186906    964.721656
# West Bank and Gaza Strip      15.00000     10.000000      2.000000
# Yemen                       3793.00000   2624.000000    474.000000
# Zambia                     18934.00000  12603.000000   1599.000000
# Zimbabwe                   14488.00000   8892.000000    633.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 229.000000  ...  334.331807  182.062827
# Albania                       7.000000  ...  334.331807  182.062827
# Algeria                     176.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                       0.000000  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip      2.000000  ...    2.000000    0.000000
# Yemen                       127.000000  ...  334.331807  182.062827
# Zambia                     1492.000000  ...  334.331807  182.062827
# Zimbabwe                   1740.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip    0.000000   2.000000   0.000000  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [212 rows x 71 columns]

# %%
extract003.year.unique()
# Out:
# array([2003], dtype=int64)

# %%
count003 = extract003.rep_meth.groupby(extract003.index)
count03 = count003.size()
count03
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 212, dtype: int64

# %%
regions003 = extract003.rep_meth.groupby(extract003.g_whoregion)
regions03 = regions003.size()
regions03
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    53
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract003.year.unique(),",",len(count03.index),"Countries were attended to and",len(regions03.index),"Regions were attended to respectively")
# Out:
# In the year [2003] , 212 Countries were attended to and 6 Regions were attended to respectively

# %%
extract004 = dataset[dataset.year == 2004]
extract004
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2004       100
# Albania                     AL  ALB            8         EUR  2004       100
# Algeria                     DZ  DZA           12         AFR  2004       100
# American Samoa              AS  ASM           16         WPR  2004       100
# Andorra                     AD  AND           20         EUR  2004       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2004       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  2004       100
# Yemen                       YE  YEM          887         EMR  2004       100
# Zambia                      ZM  ZMB          894         AFR  2004       100
# Zimbabwe                    ZW  ZWE          716         AFR  2004       100
#
#                            new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                    9976.0   7846.000000   1034.000000
# Albania                         201.0     94.000000     56.000000
# Algeria                        8405.0   6229.000000   1412.000000
# American Samoa                    3.0   7887.186906      2.000000
# Andorra                           3.0      2.000000      1.000000
# ...                               ...           ...           ...
# Wallis and Futuna Islands         1.0      1.000000    964.721656
# West Bank and Gaza Strip          4.0      2.000000    964.721656
# Yemen                          3501.0   2382.000000    483.000000
# Zambia                        17247.0  13108.000000   1156.000000
# Zimbabwe                      14581.0   7248.000000    675.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 303.000000  ...  334.331807  182.062827
# Albania                      11.000000  ...  334.331807  182.062827
# Algeria                     162.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...    0.000000    0.000000
# Andorra                     430.904174  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...    0.000000    0.000000
# West Bank and Gaza Strip      1.000000  ...    0.000000    0.000000
# Yemen                        91.000000  ...    0.000000    0.000000
# Zambia                     1363.000000  ...  334.331807  182.062827
# Zimbabwe                   1781.000000  ...    0.000000    0.000000
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa              0.000000   0.000000   0.000000  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands   0.000000   0.000000   0.000000  25.20448
# West Bank and Gaza Strip    0.000000   0.000000   0.000000  25.20448
# Yemen                       0.000000   0.000000   0.000000  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                    0.000000   0.000000   0.000000  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [211 rows x 71 columns]

# %%
extract004.year.unique()
# Out:
# array([2004], dtype=int64)

# %%
count004 = extract004.rep_meth.groupby(extract004.index)
count04 = count004.size()
count04
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 211, dtype: int64

# %%
regions004 = extract004.rep_meth.groupby(extract004.g_whoregion)
regions04 = regions004.size()
regions04
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    52
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract004.year.unique(),",",len(count04.index),"Countries were attended to and",len(regions04.index),"Regions were attended to respectively")
# Out:
# In the year [2004] , 211 Countries were attended to and 6 Regions were attended to respectively

# %%
extract005 = dataset[dataset.year == 2005]
extract005
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2005       100
# Albania                     AL  ALB            8         EUR  2005       100
# Algeria                     DZ  DZA           12         AFR  2005       100
# American Samoa              AS  ASM           16         WPR  2005       100
# Andorra                     AD  AND           20         EUR  2005       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2005       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  2005       100
# Yemen                       YE  YEM          887         EMR  2005       100
# Zambia                      ZM  ZMB          894         AFR  2005       100
# Zimbabwe                    ZW  ZWE          716         AFR  2005       100
#
#                             new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10013.00000   8295.000000    687.000000
# Albania                      196.00000     85.000000     69.000000
# Algeria                     8379.00000   6180.000000   1100.000000
# American Samoa                 4.00000      3.000000    964.721656
# Andorra                        5.00000      4.000000      0.000000
# ...                                ...           ...           ...
# Wallis and Futuna Islands  10863.51162   7887.186906    964.721656
# West Bank and Gaza Strip      12.00000      7.000000      5.000000
# Yemen                       3566.00000   2464.000000    400.000000
# Zambia                     14857.00000  11290.000000   1180.000000
# Zimbabwe                   12860.00000   7554.000000   1161.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 215.000000  ...  334.331807  182.062827
# Albania                       8.000000  ...  334.331807  182.062827
# Algeria                     164.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                       0.000000  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip      0.000000  ...  334.331807  182.062827
# Yemen                       106.000000  ...  334.331807  182.062827
# Zambia                     1178.000000  ...  334.331807  182.062827
# Zimbabwe                   1479.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [213 rows x 71 columns]

# %%
extract005.year.unique()
# Out:
# array([2005], dtype=int64)

# %%
count005 = extract005.rep_meth.groupby(extract005.index)
count05 = count005.size()
count05
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 213, dtype: int64

# %%
regions005 = extract005.rep_meth.groupby(extract005.g_whoregion)
regions05 = regions005.size()
regions05
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract005.year.unique(),",",len(count05.index),"Countries were attended to and",len(regions05.index),"Regions were attended to respectively")
# Out:
# In the year [2005] , 213 Countries were attended to and 6 Regions were attended to respectively

# %%
extract006 = dataset[dataset.year == 2006]
extract006
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2006       100
# Albania                     AL  ALB            8         EUR  2006       100
# Algeria                     DZ  DZA           12         AFR  2006       100
# American Samoa              AS  ASM           16         WPR  2006       100
# Andorra                     AD  AND           20         EUR  2006       100
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2006       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  2006       100
# Yemen                       YE  YEM          887         EMR  2006       100
# Zambia                      ZM  ZMB          894         AFR  2006       100
# Zimbabwe                    ZW  ZWE          716         AFR  2006       100
#
#                            new_sp_coh  new_sp_cur  new_sp_cmplt  new_sp_died  \
# country
# Afghanistan                   12468.0      9921.0         608.0   257.000000
# Albania                         186.0        91.0          77.0     2.000000
# Algeria                        8285.0      7148.0         374.0   156.000000
# American Samoa                    0.0         0.0           0.0     0.000000
# Andorra                           8.0         1.0           5.0   430.904174
# ...                               ...         ...           ...          ...
# Wallis and Futuna Islands         4.0         2.0           2.0     0.000000
# West Bank and Gaza Strip         16.0         8.0           7.0     1.000000
# Yemen                          3337.0      2474.0         289.0    98.000000
# Zambia                        14025.0     10762.0        1149.0   930.000000
# Zimbabwe                      16205.0      8757.0         970.0  1235.000000
#
#                            ...     mdr_coh    mdr_succ   mdr_fail   mdr_died  \
# country                    ...
# Afghanistan                ...    0.000000    0.000000   0.000000   0.000000
# Albania                    ...    1.000000    0.000000   1.000000   0.000000
# Algeria                    ...  334.331807  182.062827  30.547632  55.285032
# American Samoa             ...  334.331807  182.062827  30.547632  55.285032
# Andorra                    ...    0.000000    0.000000   0.000000   0.000000
# ...                        ...         ...         ...        ...        ...
# Wallis and Futuna Islands  ...  334.331807  182.062827  30.547632  55.285032
# West Bank and Gaza Strip   ...    0.000000    0.000000   0.000000   0.000000
# Yemen                      ...  334.331807  182.062827  30.547632  55.285032
# Zambia                     ...  334.331807  182.062827  30.547632  55.285032
# Zimbabwe                   ...    0.000000    0.000000   0.000000   0.000000
#
#                             mdr_lost   xdr_coh  xdr_succ  xdr_fail  xdr_died  \
# country
# Afghanistan                 0.000000  25.20448  8.472963  4.977812  7.383028
# Albania                     0.000000  25.20448  8.472963  4.977812  7.383028
# Algeria                    52.715739  25.20448  8.472963  4.977812  7.383028
# American Samoa             52.715739  25.20448  8.472963  4.977812  7.383028
# Andorra                     0.000000  25.20448  8.472963  4.977812  7.383028
# ...                              ...       ...       ...       ...       ...
# Wallis and Futuna Islands  52.715739  25.20448  8.472963  4.977812  7.383028
# West Bank and Gaza Strip    0.000000  25.20448  8.472963  4.977812  7.383028
# Yemen                      52.715739  25.20448  8.472963  4.977812  7.383028
# Zambia                     52.715739  25.20448  8.472963  4.977812  7.383028
# Zimbabwe                    0.000000  25.20448  8.472963  4.977812  7.383028
#
#                            xdr_lost
# country
# Afghanistan                2.884202
# Albania                    2.884202
# Algeria                    2.884202
# American Samoa             2.884202
# Andorra                    2.884202
# ...                             ...
# Wallis and Futuna Islands  2.884202
# West Bank and Gaza Strip   2.884202
# Yemen                      2.884202
# Zambia                     2.884202
# Zimbabwe                   2.884202
#
# [213 rows x 71 columns]

# %%
extract006.year.unique()
# Out:
# array([2006], dtype=int64)

# %%
count006 = extract006.rep_meth.groupby(extract006.index)
count06 = count006.size()
count06
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 213, dtype: int64

# %%
regions006 = extract006.rep_meth.groupby(extract006.g_whoregion)
regions06 = regions006.size()
regions06
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract006.year.unique(),",",len(count06.index),"Countries were attended to and",len(regions06.index),"were attended to respectively")
# Out:
# In the year [2006] , 213 Countries were attended to and 6 were attended to respectively

# %%
extract007 = dataset[dataset.year == 2007]
extract007
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2007       100
# Albania                     AL  ALB            8         EUR  2007       100
# Algeria                     DZ  DZA           12         AFR  2007       100
# American Samoa              AS  ASM           16         WPR  2007       102
# Andorra                     AD  AND           20         EUR  2007       101
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2007       100
# West Bank and Gaza Strip    PS  PSE          275         EMR  2007       100
# Yemen                       YE  YEM          887         EMR  2007       100
# Zambia                      ZM  ZMB          894         AFR  2007       102
# Zimbabwe                    ZW  ZWE          716         AFR  2007       100
#
#                             new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                13213.00000  10859.000000    663.000000
# Albania                      181.00000     90.000000     63.000000
# Algeria                     8510.00000   6699.000000    930.000000
# American Samoa                 0.00000      0.000000      0.000000
# Andorra                        2.00000      2.000000      0.000000
# ...                                ...           ...           ...
# Wallis and Futuna Islands  10863.51162   7887.186906    964.721656
# West Bank and Gaza Strip      14.00000      7.000000      6.000000
# Yemen                       3523.00000   2644.000000    323.000000
# Zambia                     13378.00000  10447.000000    882.000000
# Zimbabwe                   10583.00000   7455.000000    768.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 260.000000  ...  334.331807  182.062827
# Albania                       8.000000  ...    0.000000    0.000000
# Algeria                     180.000000  ...  334.331807  182.062827
# American Samoa                0.000000  ...    0.000000    0.000000
# Andorra                       0.000000  ...    0.000000    0.000000
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...    0.000000    0.000000
# West Bank and Gaza Strip      0.000000  ...    1.000000    0.000000
# Yemen                        97.000000  ...  334.331807  182.062827
# Zambia                      855.000000  ...  334.331807  182.062827
# Zimbabwe                    872.000000  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                     0.000000   0.000000   0.000000  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa              0.000000   0.000000   0.000000  25.20448
# Andorra                     0.000000   0.000000   0.000000  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands   0.000000   0.000000   0.000000  25.20448
# West Bank and Gaza Strip    0.000000   1.000000   0.000000  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [213 rows x 71 columns]

# %%
extract007.year.unique()
# Out:
# array([2007], dtype=int64)

# %%
count007 = extract007.rep_meth.groupby(extract007.index)
count07 = count007.size()
count07
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 213, dtype: int64

# %%
regions007 = extract007.rep_meth.groupby(extract007.g_whoregion)
regions07 = regions007.size()
regions07
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract007.year.unique(),",",len(count07.index),"Countries were attended to and",len(regions07.index),"Regions were attended to respectively")
# Out:
# In the year [2007] , 213 Countries were attended to and 6 Regions were attended to respectively

# %%
extract008 = dataset[dataset.year == 2008]
extract008
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2008       100
# Albania                     AL  ALB            8         EUR  2008       100
# Algeria                     DZ  DZA           12         AFR  2008       102
# American Samoa              AS  ASM           16         WPR  2008       102
# Andorra                     AD  AND           20         EUR  2008       101
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2008       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2008       100
# Yemen                       YE  YEM          887         EMR  2008       100
# Zambia                      ZM  ZMB          894         AFR  2008       100
# Zimbabwe                    ZW  ZWE          716         AFR  2008       100
#
#                            new_sp_coh  new_sp_cur  new_sp_cmplt  new_sp_died  \
# country
# Afghanistan                   13136.0     10936.0         593.0        267.0
# Albania                         170.0        88.0          66.0          6.0
# Algeria                        8190.0      6584.0         803.0        142.0
# American Samoa                    0.0         0.0           0.0          0.0
# Andorra                           3.0         1.0           2.0          0.0
# ...                               ...         ...           ...          ...
# Wallis and Futuna Islands         3.0         3.0           0.0          0.0
# West Bank and Gaza Strip         16.0         6.0           9.0          0.0
# Yemen                          3540.0      2671.0         334.0         97.0
# Zambia                        13173.0     10875.0         671.0        721.0
# Zimbabwe                      10370.0      6973.0         734.0        936.0
#
#                            ...     mdr_coh    mdr_succ   mdr_fail   mdr_died  \
# country                    ...
# Afghanistan                ...  334.331807  182.062827  30.547632  55.285032
# Albania                    ...  334.331807  182.062827  30.547632  55.285032
# Algeria                    ...  334.331807  182.062827  30.547632  55.285032
# American Samoa             ...    0.000000    0.000000   0.000000   0.000000
# Andorra                    ...    0.000000    0.000000   0.000000   0.000000
# ...                        ...         ...         ...        ...        ...
# Wallis and Futuna Islands  ...  334.331807  182.062827  30.547632  55.285032
# West Bank and Gaza Strip   ...    0.000000    0.000000   0.000000   0.000000
# Yemen                      ...    0.000000    0.000000   0.000000   0.000000
# Zambia                     ...  334.331807  182.062827  30.547632  55.285032
# Zimbabwe                   ...    0.000000  182.062827  30.547632  55.285032
#
#                             mdr_lost   xdr_coh  xdr_succ  xdr_fail  xdr_died  \
# country
# Afghanistan                52.715739  25.20448  8.472963  4.977812  7.383028
# Albania                    52.715739  25.20448  8.472963  4.977812  7.383028
# Algeria                    52.715739  25.20448  8.472963  4.977812  7.383028
# American Samoa              0.000000   0.00000  0.000000  0.000000  0.000000
# Andorra                     0.000000   0.00000  0.000000  0.000000  0.000000
# ...                              ...       ...       ...       ...       ...
# Wallis and Futuna Islands  52.715739  25.20448  8.472963  4.977812  7.383028
# West Bank and Gaza Strip    0.000000   0.00000  0.000000  0.000000  0.000000
# Yemen                       0.000000   0.00000  0.000000  0.000000  0.000000
# Zambia                     52.715739  25.20448  8.472963  4.977812  7.383028
# Zimbabwe                   52.715739   0.00000  8.472963  4.977812  7.383028
#
#                            xdr_lost
# country
# Afghanistan                2.884202
# Albania                    2.884202
# Algeria                    2.884202
# American Samoa             0.000000
# Andorra                    0.000000
# ...                             ...
# Wallis and Futuna Islands  2.884202
# West Bank and Gaza Strip   0.000000
# Yemen                      0.000000
# Zambia                     2.884202
# Zimbabwe                   2.884202
#
# [213 rows x 71 columns]

# %%
extract008.year.unique()
# Out:
# array([2008], dtype=int64)

# %%
count008 = extract008.rep_meth.groupby(extract008.index)
count08 = count008.size()
count08
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 213, dtype: int64

# %%
regions008 = extract008.rep_meth.groupby(extract008.g_whoregion)
regions08 = regions008.size()
regions08
# Out:
# g_whoregion
# AFR    46
# AMR    44
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract008.year.unique(),",",len(count08.index),"Countries were attended to and",len(regions08.index),"Regions were attended to respectively")
# Out:
# In the year [2008] , 213 Countries were attended to and 6 Regions were attended to respectively

# %%
extract009 = dataset[dataset.year == 2009]
extract009
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2009       100
# Albania                     AL  ALB            8         EUR  2009       100
# Algeria                     DZ  DZA           12         AFR  2009       102
# American Samoa              AS  ASM           16         WPR  2009       100
# Andorra                     AD  AND           20         EUR  2009       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2009       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2009       100
# Yemen                       YE  YEM          887         EMR  2009       100
# Zambia                      ZM  ZMB          894         AFR  2009       102
# Zimbabwe                    ZW  ZWE          716         AFR  2009       100
#
#                             new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                12497.00000  10323.000000    483.000000
# Albania                      171.00000    110.000000     43.000000
# Algeria                     8438.00000   6864.000000    854.000000
# American Samoa                 3.00000      0.000000      3.000000
# Andorra                        3.00000      1.000000      2.000000
# ...                                ...           ...           ...
# Wallis and Futuna Islands  10863.51162   7887.186906    964.721656
# West Bank and Gaza Strip      11.00000      2.000000      7.000000
# Yemen                       3557.00000   2804.000000    316.000000
# Zambia                     12995.00000  10983.000000    777.000000
# Zimbabwe                   10195.00000   7131.000000    868.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 247.000000  ...  334.331807  182.062827
# Albania                       4.000000  ...    0.000000    0.000000
# Algeria                     145.000000  ...  334.331807  182.062827
# American Samoa                0.000000  ...  334.331807  182.062827
# Andorra                       0.000000  ...    0.000000    0.000000
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip      1.000000  ...    0.000000    0.000000
# Yemen                       113.000000  ...  334.331807  182.062827
# Zambia                      722.000000  ...  334.331807  182.062827
# Zimbabwe                    807.000000  ...    1.000000    1.000000
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                     0.000000   0.000000   0.000000   0.00000
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                     0.000000   0.000000   0.000000   0.00000
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip    0.000000   0.000000   0.000000   0.00000
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                    0.000000   0.000000   0.000000   0.00000
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    0.000000  0.000000  0.000000  0.000000
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    0.000000  0.000000  0.000000  0.000000
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   0.000000  0.000000  0.000000  0.000000
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   0.000000  0.000000  0.000000  0.000000
#
# [215 rows x 71 columns]

# %%
extract009.year.unique()
# Out:
# array([2009], dtype=int64)

# %%
count009 = extract009.rep_meth.groupby(extract009.index)
count09 = count009.size()
count09
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 215, dtype: int64

# %%
regions009 = extract009.rep_meth.groupby(extract009.g_whoregion)
regions09 = regions009.size()
regions09
# Out:
# g_whoregion
# AFR    46
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract009.year.unique(),",",len(count09.index),"Countries were attended to and",len(regions09.index),"Regions were attended to respectively")
# Out:
# In the year [2009] , 215 Countries were attended to and 6 Regions were attended to respectively

# %%
extract010 = dataset[dataset.year == 2010]
extract010
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2010       100
# Albania                     AL  ALB            8         EUR  2010       100
# Algeria                     DZ  DZA           12         AFR  2010       102
# American Samoa              AS  ASM           16         WPR  2010       102
# Andorra                     AD  AND           20         EUR  2010       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2010       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2010       100
# Yemen                       YE  YEM          887         EMR  2010       100
# Zambia                      ZM  ZMB          894         AFR  2010       102
# Zimbabwe                    ZW  ZWE          716         AFR  2010       100
#
#                            new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                   12947.0  11175.000000    446.000000
# Albania                         145.0     71.000000     61.000000
# Algeria                        7894.0   6219.000000    821.000000
# American Samoa                    0.0   7887.186906    964.721656
# Andorra                           0.0      0.000000      0.000000
# ...                               ...           ...           ...
# Wallis and Futuna Islands         2.0      0.000000      2.000000
# West Bank and Gaza Strip         12.0      1.000000      9.000000
# Yemen                          3584.0   2775.000000    334.000000
# Zambia                        12639.0  10532.000000    775.000000
# Zimbabwe                      11654.0   8377.000000   1116.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 254.000000  ...  334.331807  182.062827
# Albania                       4.000000  ...    0.000000    0.000000
# Algeria                     177.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                       0.000000  ...    0.000000    0.000000
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands     0.000000  ...  334.331807  182.062827
# West Bank and Gaza Strip      0.000000  ...    0.000000    0.000000
# Yemen                        94.000000  ...  334.331807  182.062827
# Zambia                      722.000000  ...   56.000000   20.000000
# Zimbabwe                    917.000000  ...    6.000000    4.000000
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                     0.000000   0.000000   0.000000   0.00000
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                     0.000000   0.000000   0.000000   0.00000
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip    0.000000   0.000000   0.000000   0.00000
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                      3.000000   2.000000   3.000000  25.20448
# Zimbabwe                    0.000000   2.000000   0.000000   0.00000
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    0.000000  0.000000  0.000000  0.000000
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    0.000000  0.000000  0.000000  0.000000
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   0.000000  0.000000  0.000000  0.000000
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   0.000000  0.000000  0.000000  0.000000
#
# [216 rows x 71 columns]

# %%
extract010.year.unique()
# Out:
# array([2010], dtype=int64)

# %%
count010 = extract010.rep_meth.groupby(extract010.index)
count10 = count010.size()
count10
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 216, dtype: int64

# %%
regions010 = extract010.rep_meth.groupby(extract010.g_whoregion)
regions10 = regions010.size()
regions10
# Out:
# g_whoregion
# AFR    47
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract010.year.unique(),",",len(count10.index),"Countries were attended to and",len(regions10.index),"Regions were attended to respectively")
# Out:
# In the year [2010] , 216 Countries were attended to and 6 Regions were attended to respectively

# %%
extract011 = dataset[dataset.year == 2011]
extract011
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2011       100
# Albania                     AL  ALB            8         EUR  2011       100
# Algeria                     DZ  DZA           12         AFR  2011       102
# American Samoa              AS  ASM           16         WPR  2011       102
# Andorra                     AD  AND           20         EUR  2011       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2011       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2011       100
# Yemen                       YE  YEM          887         EMR  2011       100
# Zambia                      ZM  ZMB          894         AFR  2011       102
# Zimbabwe                    ZW  ZWE          716         AFR  2011       100
#
#                             new_sp_coh    new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                13789.00000  12067.000000    534.000000
# Albania                      180.00000    117.000000     51.000000
# Algeria                     7364.00000   5969.000000    807.000000
# American Samoa             10863.51162   7887.186906    964.721656
# Andorra                        1.00000      0.000000      1.000000
# ...                                ...           ...           ...
# Wallis and Futuna Islands  10863.51162   7887.186906    964.721656
# West Bank and Gaza Strip      11.00000      2.000000      9.000000
# Yemen                       3174.00000   2517.000000    285.000000
# Zambia                     12711.00000  10463.000000    671.000000
# Zimbabwe                   12596.00000   9208.000000    995.000000
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 217.000000  ...   21.000000   14.000000
# Albania                       3.000000  ...  334.331807  182.062827
# Algeria                     136.000000  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                       0.000000  ...    0.000000    0.000000
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...    0.000000  182.062827
# West Bank and Gaza Strip      0.000000  ...  334.331807  182.062827
# Yemen                        79.000000  ...    0.000000    0.000000
# Zambia                      561.000000  ...   79.000000   23.000000
# Zimbabwe                   1019.000000  ...   70.000000   57.000000
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                 0.000000   2.000000   0.000000   0.00000
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                     0.000000   0.000000   0.000000   0.00000
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                       0.000000   0.000000   0.000000   0.00000
# Zambia                      2.000000   2.000000   3.000000  25.20448
# Zimbabwe                    0.000000   9.000000   2.000000   0.00000
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                0.000000  0.000000  0.000000  0.000000
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    0.000000  0.000000  0.000000  0.000000
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      0.000000  0.000000  0.000000  0.000000
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   0.000000  0.000000  0.000000  0.000000
#
# [216 rows x 71 columns]

# %%
extract011.year.unique()
# Out:
# array([2011], dtype=int64)

# %%
count011 = extract011.rep_meth.groupby(extract011.index)
count11 = count011.size()
count11
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 216, dtype: int64

# %%
regions011 = extract011.rep_meth.groupby(extract011.g_whoregion)
regions11 = regions011.size()
regions11
# Out:
# g_whoregion
# AFR    47
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract011.year.unique(),",",len(count11.index),"Countries were attended to and",len(regions11.index),"Regions were attended to respectively")
# Out:
# In the year [2011] , 216 Countries were attended to and 6 Regions were attended to respectively

# %%
extract012 = dataset[dataset.year == 2012]
extract012
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2012       100
# Albania                     AL  ALB            8         EUR  2012       100
# Algeria                     DZ  DZA           12         AFR  2012       102
# American Samoa              AS  ASM           16         WPR  2012       102
# Andorra                     AD  AND           20         EUR  2012       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2012       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2012       100
# Yemen                       YE  YEM          887         EMR  2012       100
# Zambia                      ZM  ZMB          894         AFR  2012       102
# Zimbabwe                    ZW  ZWE          716         AFR  2012       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                    10863.51162  7887.186906    964.721656
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                      10863.51162  7887.186906    964.721656
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   10863.51162  7887.186906    964.721656
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...   38.000000   27.000000
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     430.904174  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                     430.904174  ...    0.000000  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...    0.000000  182.062827
# West Bank and Gaza Strip    430.904174  ...    0.000000    0.000000
# Yemen                       430.904174  ...  334.331807  182.062827
# Zambia                      430.904174  ...  100.000000   27.000000
# Zimbabwe                    430.904174  ...  234.000000  175.000000
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                 0.000000   6.000000   3.000000   0.00000
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739   0.00000
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip    0.000000   0.000000   0.000000   0.00000
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                      2.000000   2.000000   5.000000  25.20448
# Zimbabwe                    7.000000  26.000000  18.000000  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                0.000000  0.000000  0.000000  0.000000
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   0.000000  0.000000  0.000000  0.000000
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [216 rows x 71 columns]

# %%
extract012.year.unique()
# Out:
# array([2012], dtype=int64)

# %%
count012 = extract012.rep_meth.groupby(extract012.index)
count12 = count012.size()
count12
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 216, dtype: int64

# %%
regions012 = extract012.rep_meth.groupby(extract012.g_whoregion)
regions12 = regions012.size()
regions12
# Out:
# g_whoregion
# AFR    47
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract012.year.unique(),",",len(count12.index),"Countries were attended to and",len(regions012),"Regions were attended to respectively")
# Out:
# In the year [2012] , 216 Countries were attended to and 6 Regions were attended to respectively

# %%
extract013 = dataset[dataset.year == 2013]
extract013
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2013       100
# Albania                     AL  ALB            8         EUR  2013       100
# Algeria                     DZ  DZA           12         AFR  2013       102
# American Samoa              AS  ASM           16         WPR  2013       102
# Andorra                     AD  AND           20         EUR  2013       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2013       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2013       100
# Yemen                       YE  YEM          887         EMR  2013       100
# Zambia                      ZM  ZMB          894         AFR  2013       102
# Zimbabwe                    ZW  ZWE          716         AFR  2013       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                    10863.51162  7887.186906    964.721656
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                      10863.51162  7887.186906    964.721656
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   10863.51162  7887.186906    964.721656
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...   46.000000   29.000000
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     430.904174  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                     430.904174  ...    0.000000    0.000000
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...    0.000000    0.000000
# West Bank and Gaza Strip    430.904174  ...    0.000000    0.000000
# Yemen                       430.904174  ...    9.000000    6.000000
# Zambia                      430.904174  ...   58.000000   19.000000
# Zimbabwe                    430.904174  ...  351.000000  207.000000
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                 1.000000   6.000000   9.000000   0.00000
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                     0.000000   0.000000   0.000000   0.00000
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands   0.000000   0.000000   0.000000   2.00000
# West Bank and Gaza Strip    0.000000   0.000000   0.000000   0.00000
# Yemen                      30.547632   1.000000   2.000000  25.20448
# Zambia                      2.000000   7.000000  27.000000   0.00000
# Zimbabwe                    1.000000  43.000000  14.000000  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                0.000000  0.000000  0.000000  0.000000
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    0.000000  0.000000  0.000000  0.000000
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  2.000000  0.000000  0.000000  0.000000
# West Bank and Gaza Strip   0.000000  0.000000  0.000000  0.000000
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     0.000000  0.000000  0.000000  0.000000
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [216 rows x 71 columns]

# %%
extract013.year.unique()
# Out:
# array([2013], dtype=int64)

# %%
count013 = extract013.rep_meth.groupby(extract013.index)
count13 = count013.size()
count13
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 216, dtype: int64

# %%
regions013 = extract013.rep_meth.groupby(extract013.g_whoregion)
regions13 = regions013.size()
regions13
# Out:
# g_whoregion
# AFR    47
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract013.year.unique(),",",len(count13.index),"Countries were attended to and",len(regions13.index),"Regions were attended to respectively")
# Out:
# In the year [2013] , 216 Countries were attended to and 6 Regions were attended to respectively

# %%
extract014 = dataset[dataset.year == 2014]
extract014
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2014       100
# Albania                     AL  ALB            8         EUR  2014       100
# Algeria                     DZ  DZA           12         AFR  2014       102
# American Samoa              AS  ASM           16         WPR  2014       102
# Andorra                     AD  AND           20         EUR  2014       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2014       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2014       100
# Yemen                       YE  YEM          887         EMR  2014       100
# Zambia                      ZM  ZMB          894         AFR  2014       102
# Zimbabwe                    ZW  ZWE          716         AFR  2014       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                    10863.51162  7887.186906    964.721656
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                      10863.51162  7887.186906    964.721656
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   10863.51162  7887.186906    964.721656
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...   86.000000   56.000000
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     430.904174  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                     430.904174  ...    0.000000    0.000000
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...    0.000000    0.000000
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       430.904174  ...   41.000000   29.000000
# Zambia                      430.904174  ...   68.000000   35.000000
# Zimbabwe                    430.904174  ...  381.000000  193.000000
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                 0.000000  10.000000  20.000000   0.00000
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                     0.000000   0.000000   0.000000   0.00000
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands   0.000000   0.000000   0.000000   0.00000
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                       1.000000   6.000000   3.000000  25.20448
# Zambia                      1.000000  11.000000  20.000000   0.00000
# Zimbabwe                    6.000000  66.000000  21.000000   0.00000
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                0.000000  0.000000  0.000000  0.000000
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    0.000000  0.000000  0.000000  0.000000
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  0.000000  0.000000  0.000000  0.000000
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     0.000000  0.000000  0.000000  0.000000
# Zimbabwe                   0.000000  0.000000  0.000000  0.000000
#
# [216 rows x 71 columns]

# %%
extract014.year.unique()
# Out:
# array([2014], dtype=int64)

# %%
count014 = extract014.rep_meth.groupby(extract014.index)
count14 = count014.size()
count14
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 216, dtype: int64

# %%
regions014 = extract014.rep_meth.groupby(extract014.g_whoregion)
regions14 = regions014.size()
regions14
# Out:
# g_whoregion
# AFR    47
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract014.year.unique(),",",len(count14.index),"Countries were attended to and",len(regions14.index),"Regions were attended to respectively")
# Out:
# In the year [2014] , 216 Countries were attended to and 6 Regions were attended to respectively

# %%
extract015 = dataset[dataset.year == 2015]
extract015
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2015       100
# Albania                     AL  ALB            8         EUR  2015       100
# Algeria                     DZ  DZA           12         AFR  2015       102
# American Samoa              AS  ASM           16         WPR  2015       102
# Andorra                     AD  AND           20         EUR  2015       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2015       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2015       100
# Yemen                       YE  YEM          887         EMR  2015       100
# Zambia                      ZM  ZMB          894         AFR  2015       102
# Zimbabwe                    ZW  ZWE          716         AFR  2015       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                    10863.51162  7887.186906    964.721656
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                      10863.51162  7887.186906    964.721656
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   10863.51162  7887.186906    964.721656
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...   83.000000   53.000000
# Albania                     430.904174  ...    3.000000    3.000000
# Algeria                     430.904174  ...  334.331807  182.062827
# American Samoa              430.904174  ...    0.000000    0.000000
# Andorra                     430.904174  ...    0.000000    0.000000
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       430.904174  ...   22.000000   15.000000
# Zambia                      430.904174  ...   99.000000   59.000000
# Zimbabwe                    430.904174  ...  433.000000  189.000000
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                 0.000000  14.000000  16.000000   0.00000
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa              0.000000   0.000000   0.000000   0.00000
# Andorra                     0.000000   0.000000   0.000000   0.00000
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                       0.000000   4.000000   3.000000  25.20448
# Zambia                      0.000000  31.000000   9.000000   0.00000
# Zimbabwe                    8.000000  75.000000  22.000000   5.00000
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                0.000000  0.000000  0.000000  0.000000
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             0.000000  0.000000  0.000000  0.000000
# Andorra                    0.000000  0.000000  0.000000  0.000000
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     0.000000  0.000000  0.000000  0.000000
# Zimbabwe                   4.000000  0.000000  1.000000  0.000000
#
# [216 rows x 71 columns]

# %%
extract015.year.unique()
# Out:
# array([2015], dtype=int64)

# %%
count015 = extract015.rep_meth.groupby(extract015.index)
count15 = count015.size()
count15
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 216, dtype: int64

# %%
regions015 = extract015.rep_meth.groupby(extract015.g_whoregion)
regions15 = regions015.size()
regions15
# Out:
# g_whoregion
# AFR    47
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract015.year.unique(),",",len(count15.index),"Countries were attended to and",len(regions15.index),"Regions were attended to respectively")
# Out:
# In the year [2015] , 216 Countries were attended to and 6 Regions were attended to respectively

# %%
extract016 = dataset[dataset.year == 2016]
extract016
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2016       100
# Albania                     AL  ALB            8         EUR  2016       100
# Algeria                     DZ  DZA           12         AFR  2016       102
# American Samoa              AS  ASM           16         WPR  2016       102
# Andorra                     AD  AND           20         EUR  2016       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2016       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2016       100
# Yemen                       YE  YEM          887         EMR  2016       100
# Zambia                      ZM  ZMB          894         AFR  2016       102
# Zimbabwe                    ZW  ZWE          716         AFR  2016       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                    10863.51162  7887.186906    964.721656
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                      10863.51162  7887.186906    964.721656
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   10863.51162  7887.186906    964.721656
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...  153.000000   95.000000
# Albania                     430.904174  ...    1.000000    1.000000
# Algeria                     430.904174  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                     430.904174  ...    0.000000    0.000000
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...    0.000000    0.000000
# Yemen                       430.904174  ...   33.000000   28.000000
# Zambia                      430.904174  ...  136.000000   96.000000
# Zimbabwe                    430.904174  ...  488.000000  276.000000
#
#                             mdr_fail    mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                 4.000000   21.000000  32.000000  25.20448
# Albania                     0.000000    0.000000   0.000000   0.00000
# Algeria                    30.547632   55.285032  52.715739  25.20448
# American Samoa             30.547632   55.285032  52.715739  25.20448
# Andorra                     0.000000    0.000000   0.000000   0.00000
# ...                              ...         ...        ...       ...
# Wallis and Futuna Islands  30.547632   55.285032  52.715739  25.20448
# West Bank and Gaza Strip    0.000000    0.000000   0.000000   0.00000
# Yemen                       0.000000    3.000000   2.000000  25.20448
# Zambia                      0.000000   22.000000  13.000000   0.00000
# Zimbabwe                    0.000000  149.000000  44.000000   5.00000
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    0.000000  0.000000  0.000000  0.000000
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    0.000000  0.000000  0.000000  0.000000
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   0.000000  0.000000  0.000000  0.000000
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     0.000000  0.000000  0.000000  0.000000
# Zimbabwe                   0.000000  1.000000  2.000000  1.000000
#
# [216 rows x 71 columns]

# %%
extract016.year.unique()
# Out:
# array([2016], dtype=int64)

# %%
count016 = extract016.rep_meth.groupby(extract016.index)
count16 = count016.size()
count16
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 216, dtype: int64

# %%
regions016 = extract016.rep_meth.groupby(extract016.g_whoregion)
regions16 = regions016.size()
regions16
# Out:
# g_whoregion
# AFR    47
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract016.year.unique(),",",len(count16.index),"Countries were attended to and",len(regions16.index),"Regions were attended to respectively")
# Out:
# In the year [2016] , 216 Countries were attended to and 6 Regions were attended to respectively

# %%
extract017 = dataset[dataset.year == 2017]
extract017
# Out:
#                           iso2 iso3  iso_numeric g_whoregion  year  rep_meth  \
# country
# Afghanistan                 AF  AFG            4         EMR  2017       100
# Albania                     AL  ALB            8         EUR  2017       100
# Algeria                     DZ  DZA           12         AFR  2017       102
# American Samoa              AS  ASM           16         WPR  2017       102
# Andorra                     AD  AND           20         EUR  2017       102
# ...                        ...  ...          ...         ...   ...       ...
# Wallis and Futuna Islands   WF  WLF          876         WPR  2017       102
# West Bank and Gaza Strip    PS  PSE          275         EMR  2017       100
# Yemen                       YE  YEM          887         EMR  2017       100
# Zambia                      ZM  ZMB          894         AFR  2017       102
# Zimbabwe                    ZW  ZWE          716         AFR  2017       100
#
#                             new_sp_coh   new_sp_cur  new_sp_cmplt  \
# country
# Afghanistan                10863.51162  7887.186906    964.721656
# Albania                    10863.51162  7887.186906    964.721656
# Algeria                    10863.51162  7887.186906    964.721656
# American Samoa             10863.51162  7887.186906    964.721656
# Andorra                    10863.51162  7887.186906    964.721656
# ...                                ...          ...           ...
# Wallis and Futuna Islands  10863.51162  7887.186906    964.721656
# West Bank and Gaza Strip   10863.51162  7887.186906    964.721656
# Yemen                      10863.51162  7887.186906    964.721656
# Zambia                     10863.51162  7887.186906    964.721656
# Zimbabwe                   10863.51162  7887.186906    964.721656
#
#                            new_sp_died  ...     mdr_coh    mdr_succ  \
# country                                 ...
# Afghanistan                 430.904174  ...  334.331807  182.062827
# Albania                     430.904174  ...  334.331807  182.062827
# Algeria                     430.904174  ...  334.331807  182.062827
# American Samoa              430.904174  ...  334.331807  182.062827
# Andorra                     430.904174  ...  334.331807  182.062827
# ...                                ...  ...         ...         ...
# Wallis and Futuna Islands   430.904174  ...  334.331807  182.062827
# West Bank and Gaza Strip    430.904174  ...  334.331807  182.062827
# Yemen                       430.904174  ...  334.331807  182.062827
# Zambia                      430.904174  ...  334.331807  182.062827
# Zimbabwe                    430.904174  ...  334.331807  182.062827
#
#                             mdr_fail   mdr_died   mdr_lost   xdr_coh  \
# country
# Afghanistan                30.547632  55.285032  52.715739  25.20448
# Albania                    30.547632  55.285032  52.715739  25.20448
# Algeria                    30.547632  55.285032  52.715739  25.20448
# American Samoa             30.547632  55.285032  52.715739  25.20448
# Andorra                    30.547632  55.285032  52.715739  25.20448
# ...                              ...        ...        ...       ...
# Wallis and Futuna Islands  30.547632  55.285032  52.715739  25.20448
# West Bank and Gaza Strip   30.547632  55.285032  52.715739  25.20448
# Yemen                      30.547632  55.285032  52.715739  25.20448
# Zambia                     30.547632  55.285032  52.715739  25.20448
# Zimbabwe                   30.547632  55.285032  52.715739  25.20448
#
#                            xdr_succ  xdr_fail  xdr_died  xdr_lost
# country
# Afghanistan                8.472963  4.977812  7.383028  2.884202
# Albania                    8.472963  4.977812  7.383028  2.884202
# Algeria                    8.472963  4.977812  7.383028  2.884202
# American Samoa             8.472963  4.977812  7.383028  2.884202
# Andorra                    8.472963  4.977812  7.383028  2.884202
# ...                             ...       ...       ...       ...
# Wallis and Futuna Islands  8.472963  4.977812  7.383028  2.884202
# West Bank and Gaza Strip   8.472963  4.977812  7.383028  2.884202
# Yemen                      8.472963  4.977812  7.383028  2.884202
# Zambia                     8.472963  4.977812  7.383028  2.884202
# Zimbabwe                   8.472963  4.977812  7.383028  2.884202
#
# [216 rows x 71 columns]

# %%
extract017.year.unique()
# Out:
# array([2017], dtype=int64)

# %%
count017 = extract017.rep_meth.groupby(extract017.index)
count17 = count017.size()
count17
# Out:
# country
# Afghanistan                  1
# Albania                      1
# Algeria                      1
# American Samoa               1
# Andorra                      1
#                             ..
# Wallis and Futuna Islands    1
# West Bank and Gaza Strip     1
# Yemen                        1
# Zambia                       1
# Zimbabwe                     1
# Name: rep_meth, Length: 216, dtype: int64

# %%
regions017 = extract017.rep_meth.groupby(extract017.g_whoregion)
regions17 = regions017.size()
regions17
# Out:
# g_whoregion
# AFR    47
# AMR    46
# EMR    22
# EUR    54
# SEA    11
# WPR    36
# Name: rep_meth, dtype: int64

# %%
print("In the year",extract017.year.unique(),",",len(count17.index),"Countries were attended to and",len(regions17.index),"Regions were attended to respectively")
# Out:
# In the year [2017] , 216 Countries were attended to and 6 Regions were attended to respectively

# %% [markdown]
# ### Let's try out some other tricks using the derived country outputs for each year to form a Dataframe. This is just a test of trying out vonsistency skills
#
# ### Note that there are other ways to make this happen more efficiently

# %%
regions_series = pd.DataFrame({1994: list(regions94.values),
                               1995: list(regions95.values),
                               1996: list(regions96.values),
                               1997: list(regions97.values),
                               1998: list(regions98.values),
                              1999: list(regions99.values),
                              2000: list(regions00.values),
                              2001: list(regions01.values),
                              2002: list(regions02.values),
                              2003: list(regions03.values),
                              2004: list(regions04.values),
                              2005: list(regions05.values),
                              2006: list(regions06.values),
                              2007: list(regions07.values),
                              2008: list(regions08.values),
                              2009: list(regions09.values),
                              2010: list(regions10.values),
                              2011: list(regions11.values),
                              2012: list(regions12.values),
                              2013: list(regions13.values),
                              2014: list(regions14.values),
                              2015: list(regions15.values),
                              2016: list(regions16.values),
                              2017: list(regions17.values)})

# %%
regions94.index
# Out:
# Index(['AFR', 'AMR', 'EMR', 'EUR', 'SEA', 'WPR'], dtype='object', name='g_whoregion')

# %%
new_index = list(regions94.index)
new_index
regions_series.index = new_index
regions_series.index.name = 'who_region'
regions_series.columns.name = "Years"

# %%
regions_series
# Out:
# Years       1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  ...  \
# who_region                                                              ...
# AFR           46    46    46    46    46    46    46    46    46    46  ...
# AMR           44    44    44    44    44    44    44    44    44    44  ...
# EMR           22    22    22    22    22    22    22    22    22    22  ...
# EUR           53    53    53    53    53    53    53    53    53    53  ...
# SEA           10    10    10    10    10    10    10    10    11    11  ...
# WPR           36    36    36    36    36    36    36    36    36    36  ...
#
# Years       2008  2009  2010  2011  2012  2013  2014  2015  2016  2017
# who_region
# AFR           46    46    47    47    47    47    47    47    47    47
# AMR           44    46    46    46    46    46    46    46    46    46
# EMR           22    22    22    22    22    22    22    22    22    22
# EUR           54    54    54    54    54    54    54    54    54    54
# SEA           11    11    11    11    11    11    11    11    11    11
# WPR           36    36    36    36    36    36    36    36    36    36
#
# [6 rows x 24 columns]

# %%
regs_series = regions_series.T
regs_series
# Out:
# who_region  AFR  AMR  EMR  EUR  SEA  WPR
# Years
# 1994         46   44   22   53   10   36
# 1995         46   44   22   53   10   36
# 1996         46   44   22   53   10   36
# 1997         46   44   22   53   10   36
# 1998         46   44   22   53   10   36
# 1999         46   44   22   53   10   36
# 2000         46   44   22   53   10   36
# 2001         46   44   22   53   10   36
# 2002         46   44   22   53   11   36
# 2003         46   44   22   53   11   36
# 2004         46   44   22   52   11   36
# 2005         46   44   22   54   11   36
# 2006         46   44   22   54   11   36
# 2007         46   44   22   54   11   36
# 2008         46   44   22   54   11   36
# 2009         46   46   22   54   11   36
# 2010         47   46   22   54   11   36
# 2011         47   46   22   54   11   36
# 2012         47   46   22   54   11   36
# 2013         47   46   22   54   11   36
# 2014         47   46   22   54   11   36
# 2015         47   46   22   54   11   36
# 2016         47   46   22   54   11   36
# 2017         47   46   22   54   11   36

# %% [markdown]
# ### make a visual plot using this DataFrame

# %%
regs_series.plot(marker = '*', markersize = 3)
plt.title("Annual Value Variations", alpha = 0.85)
plt.ylabel("Values Per Region", alpha = 0.7, fontstyle = 'italic')
plt.xlabel("Years", alpha = 0.7, fontstyle = 'italic')
plt.legend(ncol = 1, loc = (1.01, 0.59))

# %%
champ_data = regs_series.iloc[-11:, 0:3]
champ_data
# Out:
# who_region  AFR  AMR  EMR
# Years
# 2007         46   44   22
# 2008         46   44   22
# 2009         46   46   22
# 2010         47   46   22
# 2011         47   46   22
# 2012         47   46   22
# 2013         47   46   22
# 2014         47   46   22
# 2015         47   46   22
# 2016         47   46   22
# 2017         47   46   22

# %% [markdown]
# ### Make a visual plot using the concatenated Output as well

# %%
champ_data.plot(kind = "bar")
plt.title("Activities Between 2007 to 2017", alpha = 0.85)
plt.legend(ncol = 1, loc = (1.01, 0.77))
plt.ylabel("Number of Countries in Region", alpha = 0.7, fontstyle ='italic')
# Out:
# Text(0, 0.5, 'Number of Countries in Region')

# %%
regions_comb = pd.concat([regions94,regions95,regions96,regions97,regions98,regions99,regions00,regions01,regions02,regions03,regions04,regions05,regions06,regions07,regions08,regions09,regions10,regions11,regions12, regions13,regions14,regions15,regions16,regions17], keys =["1994",'1995',"1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"])
regions_comb
# Out:
#       g_whoregion
# 1994  AFR            46
#       AMR            44
#       EMR            22
#       EUR            53
#       SEA            10
#                      ..
# 2017  AMR            46
#       EMR            22
#       EUR            54
#       SEA            11
#       WPR            36
# Name: rep_meth, Length: 144, dtype: int64

# %%
region_comb = regions_comb.unstack()
region_comb
# Out:
# g_whoregion  AFR  AMR  EMR  EUR  SEA  WPR
# 1994          46   44   22   53   10   36
# 1995          46   44   22   53   10   36
# 1996          46   44   22   53   10   36
# 1997          46   44   22   53   10   36
# 1998          46   44   22   53   10   36
# 1999          46   44   22   53   10   36
# 2000          46   44   22   53   10   36
# 2001          46   44   22   53   10   36
# 2002          46   44   22   53   11   36
# 2003          46   44   22   53   11   36
# 2004          46   44   22   52   11   36
# 2005          46   44   22   54   11   36
# 2006          46   44   22   54   11   36
# 2007          46   44   22   54   11   36
# 2008          46   44   22   54   11   36
# 2009          46   46   22   54   11   36
# 2010          47   46   22   54   11   36
# 2011          47   46   22   54   11   36
# 2012          47   46   22   54   11   36
# 2013          47   46   22   54   11   36
# 2014          47   46   22   54   11   36
# 2015          47   46   22   54   11   36
# 2016          47   46   22   54   11   36
# 2017          47   46   22   54   11   36

# %%
region_comb.index.name = "Year"
region_comb.columns.name = "Regions"
region_comb.head()
# Out:
# Regions  AFR  AMR  EMR  EUR  SEA  WPR
# Year
# 1994      46   44   22   53   10   36
# 1995      46   44   22   53   10   36
# 1996      46   44   22   53   10   36
# 1997      46   44   22   53   10   36
# 1998      46   44   22   53   10   36

# %% [markdown]
# ### Make a visual plot using this output as well

# %%
region_comb.plot(marker = "+")
plt.ylabel("Number of Countries in Region", alpha = 0.7, fontstyle ='italic')
plt.xlabel("Years", alpha = 0.7, fontstyle = 'italic')
plt.legend(ncol = 1, loc = (1.01, 0.58))

# %% [markdown]
# ### Like always, there's no limit to length at which you can unleash and utilize your imagination
#
# ### Feel free to do more just as your creativity can take you.

# %% [markdown]
# ### There's less visual plotting in this lesson, and i believe that leaves you with a huge opportunity to make that a personal task.
#
# ### Make as many visual plots as you deem fit, to build you competence using the Matplotlib Library

# %% [markdown]
# ### This marks the end of another lesson using Python's amazing Libraries for Data Science / Data Analysis. Be encouraed and let your creativity guide you on this career path. Nerr feel intimidated even if you're doing it a vit poorly. Keep putting in some extra effort. It's just a matter of time before you gain mastery of it

# %% [markdown]
# ### Till I bring another lesson your way,
#
# # Happy Learning !!!
